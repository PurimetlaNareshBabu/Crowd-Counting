# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pylab import *

# %%
# %cd /content/drive/MyDrive/yolobtp/darknet
# Out:
# /content/drive/MyDrive/yolobtp/darknet

# %%
# %cd /content/drive/MyDrive/yolobtp/darknet 
# !make
# !chmod +x ./darknet
# Out:
# /content/drive/MyDrive/yolobtp/darknet
# chmod +x *.sh

# %%
# %cd /content/drive/MyDrive/yolobtp/darknet 
# !./darknet detector map data/obj.data cfg/yolov3_custom.cfg backup/yolov3_custom_best.weights
# Out:
# /content/drive/MyDrive/yolobtp/darknet
# CUDA status Error: file: ./src/dark_cuda.c : () : line: 38 : build time: Feb  6 2022 - 19:24:57
#
#  CUDA Error: no CUDA-capable device is detected
# Darknet error location: ./src/dark_cuda.c, check_error, line #69
# CUDA Error: no CUDA-capable device is detected: Bad file descriptor

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
  bbox, label, conf = cv.detect_common_objects(image)
  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  print(bbox, label, conf)
  print('No of persons in the image is'+str(label.count('person')))
  plt.show()

# %%
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov3_custom.cfg
# !sed -i 's/subdivisions=32/subdivisions=1/' yolov3_custom.cfg
# %cd ..
# Out:
# /content/drive/MyDrive/yolobtp/darknet/cfg
# /content/drive/MyDrive/yolobtp/darknet

# %%
from matplotlib import pyplot as plt

# %%
# !./darknet detector test data/obj.data cfg/yolov3_custom.cfg backup/yolov3_custom_best.weights /content/drive/MyDrive/yolobtp/oxfordtowncenter/aug_images/aug1_1199.jpg -thresh 0.2
plt.imshow(plt.imread('predictions.jpg'))
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
